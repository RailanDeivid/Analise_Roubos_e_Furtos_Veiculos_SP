# %%
import pandas as pd
import os, glob
import numpy as np
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', 100)

# %%
# Diretório onde estão os arquivos Excel
db_path = os.path.join(os.getcwd(), '..', '..', 'data','raw')                 
todos_arquivos = glob.glob(os.path.join(db_path, "*.xlsx"))    

# Inicializa uma lista vazia para armazenar os DataFrames individuais
dfs = []

# Itera sobre cada arquivo Excel encontrado
for arquivo in todos_arquivos:
    # Lê o arquivo excel e adiciona o DataFrame à lista
    df_temp = pd.read_excel(arquivo)
    dfs.append(df_temp)

# Concatena todos os DataFrames da lista em um único DataFrame
df = pd.concat(dfs, ignore_index=True)

# Exibe as primeiras linhas do DataFrame resultante
df.drop_duplicates(inplace=True)
cols_use = ['DATA_OCORRENCIA_BO', 'HORA_OCORRENCIA', 'ANO_BO', 'NUM_BO', 'FLAG_ATO_INFRACIONAL', 'CIDADE', 'BAIRRO', 'CEP', 'LOGRADOURO', 'NUMERO_LOGRADOURO',
            'LATITUDE', 'LONGITUDE', 'DESCR_OCORRENCIA_VEICULO', 'DESCR_TIPO_VEICULO', 'DESCR_MARCA_VEICULO', 'DESC_COR_VEICULO']
df = df[cols_use]
df.head()
# Out:
#   DATA_OCORRENCIA_BO HORA_OCORRENCIA  ANO_BO  NUM_BO FLAG_ATO_INFRACIONAL  \
# 0         2022-11-24        17:40:00    2022  JS5624                    N
# 1         2022-11-24        17:40:00    2022  JS5624                    N
# 2         2022-11-24        17:40:00    2022  JS5624                    N
# 3         2022-11-24        17:40:00    2022  JS5624                    N
# 4         2022-11-24        17:40:00    2022  JS5624                    N
#
#     CIDADE     BAIRRO        CEP            LOGRADOURO  NUMERO_LOGRADOURO  \
# 0  S.PAULO  LIBERDADE  1502000.0  AVENIDA DA LIBERDADE              130.0
# 1  S.PAULO  LIBERDADE  1502000.0  AVENIDA DA LIBERDADE              130.0
# 2  S.PAULO  LIBERDADE  1502000.0  AVENIDA DA LIBERDADE              130.0
# 3  S.PAULO  LIBERDADE  1502000.0  AVENIDA DA LIBERDADE              130.0
# 4  S.PAULO  LIBERDADE  1502000.0  AVENIDA DA LIBERDADE              130.0
#
#     LATITUDE  LONGITUDE DESCR_OCORRENCIA_VEICULO DESCR_TIPO_VEICULO  \
# 0 -23.557245 -46.636418    Localizado / Entregue          Motociclo
# 1 -23.557245 -46.636418    Localizado / Entregue          Motociclo
# 2 -23.557245 -46.636418    Localizado / Entregue          Motociclo
# 3 -23.557245 -46.636418    Localizado / Entregue          Motociclo
# 4 -23.557245 -46.636418    Localizado / Entregue          Motociclo
#
#       DESCR_MARCA_VEICULO DESC_COR_VEICULO
# 0        HONDA/CG 160 FAN         Vermelho
# 1  KAWASAKI/VERSYS 650 TR            Verde
# 2        HONDA/CG 160 FAN         Vermelho
# 3  KAWASAKI/VERSYS 650 TR            Verde
# 4        HONDA/CG 160 FAN         Vermelho

# %% [markdown]
# ## Tratamento de dados nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413118 entries, 0 to 413117
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DATA_OCORRENCIA_BO        407400 non-null  datetime64[ns]
#  1   HORA_OCORRENCIA           374725 non-null  object
#  2   ANO_BO                    413118 non-null  int64
#  3   NUM_BO                    413118 non-null  object
#  4   FLAG_ATO_INFRACIONAL      413118 non-null  object
#  5   CIDADE                    413118 non-null  object
#  6   BAIRRO                    405584 non-null  object
#  7   CEP                       343581 non-null  float64
#  8   LOGRADOURO                413118 non-null  object
#  9   NUMERO_LOGRADOURO         380020 non-null  float64
#  10  LATITUDE                  397948 non-null  float64
#  11  LONGITUDE                 397948 non-null  float64
#  12  DESCR_OCORRENCIA_VEICULO  413118 non-null  object
#  13  DESCR_TIPO_VEICULO        413118 non-null  object
#  14  DESCR_MARCA_VEICULO       413118 non-null  object
#  15  DESC_COR_VEICULO          413118 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(10)
# memory usage: 50.4+ MB

# %% [markdown]
# * Alterando types das colunas

# %%
df.columns.tolist()
# Out:
# ['DATA_OCORRENCIA_BO',
#  'HORA_OCORRENCIA',
#  'ANO_BO',
#  'NUM_BO',
#  'FLAG_ATO_INFRACIONAL',
#  'CIDADE',
#  'BAIRRO',
#  'CEP',
#  'LOGRADOURO',
#  'NUMERO_LOGRADOURO',
#  'LATITUDE',
#  'LONGITUDE',
#  'DESCR_OCORRENCIA_VEICULO',
#  'DESCR_TIPO_VEICULO',
#  'DESCR_MARCA_VEICULO',
#  'DESC_COR_VEICULO']

# %%
df.isnull().sum()
# Out:
# DATA_OCORRENCIA_BO           5718
# HORA_OCORRENCIA             38393
# ANO_BO                          0
# NUM_BO                          0
# FLAG_ATO_INFRACIONAL            0
# CIDADE                          0
# BAIRRO                       7534
# CEP                         69537
# LOGRADOURO                      0
# NUMERO_LOGRADOURO           33098
# LATITUDE                    15170
# LONGITUDE                   15170
# DESCR_OCORRENCIA_VEICULO        0
# DESCR_TIPO_VEICULO              0
# DESCR_MARCA_VEICULO             0
# DESC_COR_VEICULO                0
# dtype: int64

# %%
nan_cols = [i for i in df.columns if df[i].isnull().sum() >= 1]
for i in nan_cols:
    print(f"{i}:", "contém", np.round(df[i].isnull().mean() * 100, 2),
          '% dos dados nulos', 'e um total de',
          np.round(df[i].isnull().sum(), 4,), "linhas afetadas")
# Out:
# DATA_OCORRENCIA_BO: contém 1.38 % dos dados nulos e um total de 5718 linhas afetadas
# HORA_OCORRENCIA: contém 9.29 % dos dados nulos e um total de 38393 linhas afetadas
# BAIRRO: contém 1.82 % dos dados nulos e um total de 7534 linhas afetadas
# CEP: contém 16.83 % dos dados nulos e um total de 69537 linhas afetadas
# NUMERO_LOGRADOURO: contém 8.01 % dos dados nulos e um total de 33098 linhas afetadas
# LATITUDE: contém 3.67 % dos dados nulos e um total de 15170 linhas afetadas
# LONGITUDE: contém 3.67 % dos dados nulos e um total de 15170 linhas afetadas

# %% [markdown]
# * Decisão sobre dados nulos
#     * Os dados nulos estão bem distribuidos, e como irei fazer analises distentas e variadas não vejo impacto em seguir com esses danos nulos.
#     * Apenas irei fazer algunas substituições nos dados nulos de algumas variaveis.

# %% [markdown]
# ### Analisando variaveis

# %%
# Obter categorias únicas de cada coluna
unique_categories = {col: df[col].unique() for col in df.columns}

# Exibir as categorias únicas de cada coluna
for col, categories in unique_categories.items():
    print(f"Coluna: {col}")
    print(f"Categorias únicas: {categories}\n")
# Out:
# Coluna: DATA_OCORRENCIA_BO
# Categorias únicas: <DatetimeArray>
# ['2022-11-24 00:00:00', '2023-01-03 00:00:00', '2023-01-05 00:00:00',
#  '2023-01-06 00:00:00', '2023-01-07 00:00:00', '2023-01-10 00:00:00',
#  '2023-01-13 00:00:00', '2023-01-18 00:00:00', '2023-01-19 00:00:00',
#  '2023-01-20 00:00:00',
#  ...
#  '2021-06-01 00:00:00', '2013-04-28 00:00:00', '2018-10-21 00:00:00',
#  '2018-11-05 00:00:00', '2014-05-04 00:00:00', '2014-07-18 00:00:00',
#  '2022-09-18 00:00:00', '2014-11-15 00:00:00', '2024-06-06 00:00:00',
#  '2024-06-11 00:00:00']
# Length: 1465, dtype: datetime64[ns]
#
# Coluna: HORA_OCORRENCIA
# Categorias únicas: [datetime.time(17, 40) datetime.time(1, 0) datetime.time(21, 30, 9) ...
#  datetime.time(8, 32, 15) datetime.time(6, 10, 4)
#  datetime.time(16, 35, 48)]
#
# Coluna: ANO_BO
# Categorias únicas: [2022 2023 2021 2024]
#
# Coluna: NUM_BO
# Categorias únicas: ['JS5624' 'AC0542' 'AG0290' ... 'GK7821' 'GE3228' 'GQ5787']
#
# Coluna: FLAG_ATO_INFRACIONAL
# Categorias únicas: ['N' 'S']
#
# Coluna: CIDADE
# Categorias únicas: ['S.PAULO' 'FERRAZ DE VASCONCELOS' 'OSASCO' 'EMBU DAS ARTES' 'DIADEMA'
#  'CRUZEIRO' 'APARECIDA' 'CACHOEIRA PAULISTA' 'CANAS' 'CUNHA'
#  'GUARATINGUETA' 'LORENA' 'POTIM' 'IGARATA' 'JACAREI' 'PARAIBUNA'
#  'S.BRANCA' 'CACAPAVA' 'MONTEIRO LOBATO' 'S.JOSE DOS CAMPOS'
#  'CARAGUATATUBA' 'S.SEBASTIAO' 'UBATUBA' 'CAMPOS DO JORDAO'
#  'PINDAMONHANGABA' 'REDENCAO DA SERRA' 'S.BENTO DO SAPUCAI' 'TAUBATE'
#  'TREMEMBE' 'ANDRADINA' 'CASTILHO' 'ILHA SOLTEIRA' 'ITAPURA'
#  'PEREIRA BARRETO' 'ARACATUBA' 'AURIFLAMA' 'BARBOSA' 'BENTO DE ABREU'
#  'BILAC' 'BIRIGUI' 'BURITAMA' 'CLEMENTINA' 'GUARARAPES' 'PENAPOLIS'
#  'RUBIACEA' 'TURIUBA' 'CAMPINAS' 'SUMARE' 'PAULINIA' 'VALINHOS' 'VINHEDO'
#  'INDAIATUBA' 'AGUAS DE LINDOIA' 'AMPARO' 'ATIBAIA' 'BRAGANCA PAULISTA'
#  'JOANOPOLIS' 'LINDOIA' 'NAZARE PAULISTA' 'PINHALZINHO' 'PIRACAIA'
#  'SERRA NEGRA' 'SOCORRO' 'TUIUTI' 'CABREUVA' 'CAMPO LIMPO PAULISTA'
#  'ITATIBA' 'ITUPEVA' 'JARINU' 'JUNDIAI' 'LOUVEIRA' 'MORUNGABA'
#  'VARZEA PAULISTA' 'ESTIVA GERBI' 'ITAPIRA' 'JAGUARIUNA' 'MOGI GUACU'
#  'MOGI MIRIM' 'PEDREIRA' 'S.ANTONIO DE POSSE' 'AMERICO BRASILIENSE'
#  'ARARAQUARA' 'BOA ESPERANCA DO SUL' 'BORBOREMA' 'FERNANDO PRESTES'
#  'GAVIAO PEIXOTO' 'IBITINGA' 'ITAPOLIS' 'MATAO' 'NOVA EUROPA' 'RINCAO'
#  'S.ERNESTINA' 'S.LUCIA' 'TABATINGA' 'TAQUARITINGA' 'BARRETOS' 'GUAIRA'
#  'COLINA' 'JABORANDI' 'OLIMPIA' 'SEVERINIA' 'BEBEDOURO'
#  'MONTE AZUL PAULISTA' 'TAIUVA' 'TERRA ROXA' 'VIRADOURO' 'ARAMINA'
#  'BATATAIS' 'FRANCA' 'GUARA' 'IGARAPAVA' 'ITUVERAVA' 'MIGUELOPOLIS'
#  'PATROCINIO PAULISTA' 'PEDREGULHO' 'RIBEIRAO CORRENTE' 'RIFAINA'
#  'S.JOSE DA BELA VISTA' 'ALTINOPOLIS' 'BRODOWSKI' 'CAJURU'
#  'CASSIA DOS COQUEIROS' 'CRAVINHOS' 'JARDINOPOLIS' 'RIBEIRAO PRETO'
#  'S.ANTONIO DA ALEGRIA' 'S.SIMAO' 'SERRA AZUL' 'SERRANA' 'IPUA'
#  'MORRO AGUDO' 'ORLANDIA' 'S.JOAQUIM DA BARRA' 'DESCALVADO' 'DOURADO'
#  'IBATE' 'PORTO FERREIRA' 'RIBEIRAO BONITO' 'S.CARLOS'
#  'S.RITA PASSA QUATRO' 'BARRINHA' 'DUMONT' 'GUARIBA' 'JABOTICABAL'
#  'MONTE ALTO' 'PITANGUEIRAS' 'PONTAL' 'PRADOPOLIS' 'SERTAOZINHO' 'AGUDOS'
#  'AVAI' 'BAURU' 'LENCOIS PAULISTA' 'MACATUBA' 'PEDERNEIRAS' 'PIRATININGA'
#  'REGINOPOLIS' 'BARIRI' 'BARRA BONITA' 'BORACEIA' 'DOIS CORREGOS'
#  'IGARACU DO TIETE' 'ITAJU' 'ITAPUI' 'JAU' 'CAFELANDIA' 'GUAICARA' 'LINS'
#  'PROMISSAO' 'URU' 'ALVINLANDIA' 'GALIA' 'GARCA' 'MARILIA' 'ORIENTE'
#  'CANITAR' 'IPAUSSU' 'OURINHOS' 'S.CRUZ DO RIO PARDO' 'QUEIROZ' 'TUPA'
#  'CATANDUVA' 'ELISIARIO' 'PINDORAMA' 'TABAPUA' 'ESTRELA D OESTE'
#  'FERNANDOPOLIS' 'MERIDIANO' 'JALES' 'PARANAPUA' 'S.FE DO SUL' 'URANIA'
#  'IRAPUA' 'ITAJOBI' 'NOVO HORIZONTE' 'URUPES' 'BADY BASSITT' 'BALSAMO'
#  'CEDRAL' 'GUAPIACU' 'IPIGUA' 'JACI' 'JOSE BONIFACIO' 'MIRASSOL'
#  'MONTE APRAZIVEL' 'NOVA ALIANCA' 'NOVA GRANADA' 'S.JOSE DO RIO PRETO'
#  'TANABI' 'UBARANA' 'COSMORAMA' 'FLOREAL' 'MACAUBAL' 'MONCOES' 'PARISI'
#  'VALENTIM GENTIL' 'VOTUPORANGA' 'ITANHAEM' 'ITARIRI' 'MONGAGUA'
#  'PEDRO DE TOLEDO' 'PERUIBE' 'CAJATI' 'CANANEIA' 'ELDORADO'
#  'PARIQUERA-ACU' 'PRAIA GRANDE' 'S.VICENTE' 'IGUAPE' 'ILHA COMPRIDA'
#  'JUQUIA' 'MIRACATU' 'REGISTRO' 'BERTIOGA' 'CUBATAO' 'GUARUJA' 'SANTOS'
#  'AVARE' 'CERQUEIRA CESAR' 'CORONEL MACEDO' 'FARTURA' 'ITAI' 'ITAPORANGA'
#  'MANDURI' 'PARANAPANEMA' 'TAQUARITUBA' 'BOTUCATU' 'CONCHAS' 'ITATINGA'
#  'LARANJAL PAULISTA' 'PARDINHO' 'ANGATUBA' 'BOITUVA' 'ARACARIGUAMA'
#  'CAMPINA MONTE ALEGRE' 'CAPELA DO ALTO' 'CESARIO LANGE' 'ITAPETININGA'
#  'QUADRA' 'S.MIGUEL ARCANJO' 'SARAPUI' 'TATUI' 'APIAI' 'BURI'
#  'CAPAO BONITO' 'ITABERA' 'ITAPEVA' 'ITARARE' 'TAQUARIVAI' 'ALUMINIO'
#  'ARACOIABA DA SERRA' 'IBIUNA' 'IPERO' 'SOROCABA' 'ITU' 'MAIRINQUE'
#  'PIEDADE' 'PILAR DO SUL' 'PORTO FELIZ' 'S.ROQUE' 'SALTO'
#  'SALTO DE PIRAPORA' 'TAPIRAI' 'TIETE' 'VOTORANTIM' 'INUBIA PAULISTA'
#  'LUCELIA' 'PACAEMBU' 'ASSIS' 'CANDIDO MOTA' 'IBIRAREMA' 'TARUMA'
#  'DRACENA' 'TUPI PAULISTA' 'ALVARES MACHADO' 'NARANDIBA'
#  'PRESIDENTE PRUDENTE' 'RANCHARIA' 'REGENTE FEIJO' 'SANDOVALINA'
#  'PRESIDENTE EPITACIO' 'TEODORO SAMPAIO' 'AMERICANA' 'LIMEIRA'
#  'ARTUR NOGUEIRA' 'COSMOPOLIS' 'ENGENHEIRO COELHO' 'HORTOLANDIA'
#  'MONTE MOR' 'NOVA ODESSA' 'S.BARBARA D OESTE' 'CASA BRANCA' 'ITOBI'
#  'MOCOCA' 'S.CRUZ DAS PALMEIRAS' 'S.JOSE DO RIO PARDO' 'TAMBAU' 'ARARAS'
#  'CONCHAL' 'CORDEIROPOLIS' 'IRACEMAPOLIS' 'LEME' 'PIRASSUNUNGA'
#  'S.CRUZ DA CONCEICAO' 'AGUAS DE SAO PEDRO' 'CAPIVARI' 'ELIAS FAUSTO'
#  'MOMBUCA' 'PIRACICABA' 'RAFARD' 'RIO DAS PEDRAS' 'S.PEDRO' 'SALTINHO'
#  'BROTAS' 'CORUMBATAI' 'IPEUNA' 'ITIRAPINA' 'RIO CLARO' 'S.GERTRUDES'
#  'TORRINHA' 'AGUAI' 'DIVINOLANDIA' 'ESPIRITO STO. PINHAL'
#  'S.ANTONIO DO JARDIM' 'S.JOAO DA BOA VISTA' 'S.SEBASTIAO DA GRAMA'
#  'VARGEM GRANDE DO SUL' 'BARUERI' 'JANDIRA' 'CARAPICUIBA' 'COTIA'
#  'ITAPEVI' 'PIRAPORA BOM JESUS' 'SANTANA DE PARNAIBA'
#  'VARGEM GRANDE PAULISTA' 'CAIEIRAS' 'CAJAMAR' 'FRANCISCO MORATO'
#  'FRANCO DA ROCHA' 'MAIRIPORA' 'ARUJA' 'GUARULHOS' 'S.ISABEL'
#  'BIRITIBA-MIRIM' 'GUARAREMA' 'ITAQUAQUECETUBA' 'MOGI DAS CRUZES'
#  'MARAPOAMA' 'POA' 'SALESOPOLIS' 'SUZANO' 'S.BERNARDO DO CAMPO'
#  'S.CAETANO DO SUL' 'MAUA' 'RIBEIRAO PIRES' 'RIO GRANDE DA SERRA'
#  'S.ANDRE' 'EMBU-GUACU' 'ITAPECERICA DA SERRA' 'JUQUITIBA'
#  'S.LOURENCO DA SERRA' 'TABOAO DA SERRA' 'LAVRINHAS' 'QUELUZ' 'ROSEIRA'
#  'JAMBEIRO' 'ILHABELA' 'S.LUIZ DO PARAITINGA' 'GUARACAI'
#  'NOVA INDEPENDENCIA' 'TRES LAGOAS' 'ALTO ALEGRE' 'COROADOS' 'SELVIRIA'
#  'VALPARAISO' 'BOM JESUS DOS PERDOES' 'MONTE ALEGRE DO SUL' 'HOLAMBRA'
#  'PIRANGI' 'VISTA ALEGRE DO ALTO' 'BURITIZAL' 'CRISTAIS PAULISTA'
#  'ITIRAPUA' 'RESTINGA' 'GUATAPARA' 'S.CRUZ DA ESPERANCA'
#  'S.ROSA DE VITERBO' 'NUPORANGA' 'AREALVA' 'IACANGA' 'MINEIROS DO TIETE'
#  'POMPEIA' 'VERA CRUZ' 'SALTO GRANDE' 'IACRI' 'QUINTANA' 'CATIGUA'
#  'PALMARES PAULISTA' 'PARAISO' 'GUARANI D OESTE' 'OUROESTE' 'RUBINEIA'
#  'ICEM' 'NIPOA' 'POTIRENDABA' 'ALVARES FLORENCE' 'NHANDEARA'
#  'BARRA DO TURVO' 'IARAS' 'PIRAJU' 'BOFETE' 'PEREIRAS' 'PORANGABA'
#  'S.MANUEL' 'ALAMBARI' 'CERQUILHO' 'GUAPIARA' 'ITAPIRAPUA PAULISTA'
#  'FLORINIA' 'PALMITAL' 'NOVA GUATAPORANGA' 'PANORAMA' 'IEPE'
#  'MARTINOPOLIS' 'PIRAPOZINHO' 'TARABAI' 'CAIUA' 'PRESIDENTE VENCESLAU'
#  'TAPIRATIBA' 'CHARQUEADA' 'PIQUETE' 'OUTRO PAIS' 'MURUTINGA DO SUL'
#  'BRAUNA' 'GASTAO VIDIGAL' 'GLICERIO' 'LOURDES' 'DOBRADA' 'MOTUCA'
#  'GUARACI' 'TAIACU' 'LUIS ANTONIO' 'SALES OLIVEIRA' 'BOREBI' 'DUARTINA'
#  'PIRAJUI' 'BOCAINA' 'GUAIMBE' 'GUARANTA' 'QUATA' 'INDIAPORA' 'DIRCE REIS'
#  'S.ALBERTINA' 'S.FRANCISCO' 'MENDONCA' 'ONDA VERDE' 'PALESTINA'
#  'PLANALTO' 'UCHOA' 'AMERICO DE CAMPOS' 'JACUPIRANGA' 'PRATANIA'
#  'BARRA DO CHAPEU' 'NOVA CAMPINA' 'ADAMANTINA' 'OSVALDO CRUZ' 'MARACAI'
#  'PARAGUACU PAULISTA' 'JUNQUEIROPOLIS' 'OURO VERDE' 'PAULICEIA'
#  'ALFREDO MARCONDES' 'JOAO RAMALHO' 'NANTES' 'MIRANTE PARANAPANEMA'
#  'ROSANA' 'ANALANDIA' 'AGUAS DA PRATA' 'MIRANDOPOLIS' 'AVANHANDAVA'
#  'S.JOAO DE IRACEMA' 'SANTOPOLIS DO AGUAPEI' 'VARGEM' 'CAJOBI' 'COLOMBIA'
#  'PONGAI' 'OCAUCU' 'RIBEIRAO DO SUL' 'BASTOS' 'S.ADELIA' 'MARINOPOLIS'
#  'PALMEIRA D OESTE' 'TRES FRONTEIRAS' 'IBIRA' 'NEVES PAULISTA' 'CARDOSO'
#  'SETE BARRAS' 'AGUAS DE SANTA BARBARA' 'TAGUAI' 'TEJUPA' 'ANHEMBI'
#  'RIBEIRAO BRANCO' 'CAMPOS NOVOS PAULISTA' 'ANHUMAS'
#  'EUCLIDES DA CUNHA PTA' 'PEDRA BELA' 'TAQUARAL' 'GETULINA'
#  'ESPIRITO S.DO TURVO' 'HERCULANDIA' 'SALES' 'ORINDIUVA' 'SARUTAIA'
#  'GUAREI' 'JUMIRIM' 'FLORA RICA' 'S.ANASTACIO' 'CACONDE' 'LAGOINHA'
#  'NATIVIDADE DA SERRA' 'JERIQUARA' 'ECHAPORA' 'CHAVANTES'
#  'S.PEDRO DO TURVO' 'RINOPOLIS' 'BOM SUCESSO DE ITARARE' 'RIBEIRAO GRANDE'
#  'CRUZALIA' 'PRESIDENTE BERNARDES' 'S.JOSE DO BARREIRO' 'BALBINOS'
#  'PRESIDENTE ALVES' 'ARIRANHA' 'ZACARIAS' 'RIVERSUL' 'TACIBA'
#  'S.ANTONIO DO PINHAL' 'S.ANTONIO DE ARACANGUA' 'TIMBURI' 'POPULINA'
#  'MIRASSOLANDIA' 'PAULO DE FARIA' 'IRAPURU' 'PEDRINHAS PAULISTA'
#  'S.MARIA DA SERRA' 'GUZOLANDIA' 'CANDIDO RODRIGUES' 'PARAPUA'
#  'DOLCINOPOLIS' 'SEBASTIANOPOLIS DO SUL' 'MARIAPOLIS' 'S.EXPEDITO'
#  'CABRALIA PAULISTA' 'MACEDONIA' 'ADOLFO' 'RIO DAS OSTRAS' 'ARANDU'
#  'TRABIJU' 'BERNARDINO DE CAMPOS' 'S.JOAO DUAS PONTES' 'RIBEIRA'
#  'SUD MENNUCCI' 'ALTAIR' 'NOVAIS' 'PONTALINDA' 'S.JOAO DO PAU D ALHO'
#  'ALVARO DE CARVALHO' 'PIACATU' 'SABINO' 'APARECIDA D OESTE' 'INDIANA'
#  'BREJO ALEGRE' 'BARAO DE ANTONINA' 'PAULISTANIA' 'TURMALINA' 'LUIZIANIA'
#  'MIRA ESTRELA' 'NOVA CANAA PAULISTA' 'MAGDA']
#
# Coluna: BAIRRO
# Categorias únicas: ['LIBERDADE' 'CENTRO HISTÓRICO DE SÃO PAULO' 'SE' ... 'JD. DO EDEM'
#  'JD. SAMPAIO' 'JARDIM KUABARA']
#
# Coluna: CEP
# Categorias únicas: [1502000. 1016000. 1514060. ... 6756030. 6783091. 6824400.]
#
# Coluna: LOGRADOURO
# Categorias únicas: ['AVENIDA DA LIBERDADE' 'RUA VENCESLAU BRÁS' 'VIADUTO DO GLICÉRIO' ...
#  'RUA MARINO MARTINS DE OLIVEIRA' 'AVENIDA APRÍGIO BEZERRA DA SILVA'
#  'RUA SEBASTIÃO PAULINO TEIXEIRA']
#
# Coluna: NUMERO_LOGRADOURO
# Categorias únicas: [ 130.  801.    0. ... 6843. 2377. 4645.]
#
# Coluna: LATITUDE
# Categorias únicas: [-23.55724483 -23.5495014  -23.5562699  ... -23.43495722 -23.44008972
#  -23.42316041]
#
# Coluna: LONGITUDE
# Categorias únicas: [-46.63641779 -46.6330166  -46.6306532  ... -46.49354605 -46.48610498
#  -46.33779165]
#
# Coluna: DESCR_OCORRENCIA_VEICULO
# Categorias únicas: ['Localizado / Entregue' 'Furtado' 'Roubado']
#
# Coluna: DESCR_TIPO_VEICULO
# Categorias únicas: ['Motociclo' 'Automovel' 'Motoneta' 'Caminhonete' 'Utilitário' 'Camioneta'
#  'Caminhão' 'Não informado' 'Caminhão trator' 'Semi-reboque'
#  'Micro-onibus' 'Reboque' 'Onibus' 'Ciclomoto' 'Trator rodas'
#  'Inexistente' 'Trator misto' 'Side-car' 'Bicicleta' 'Carro de mão'
#  'Motor casa' 'Triciclo' 'Quadriciclo' 'Chassi-plataforma' 'Charrete'
#  'Trator esteiras' 'Bonde']
#
# Coluna: DESCR_MARCA_VEICULO
# Categorias únicas: ['HONDA/CG 160 FAN' 'KAWASAKI/VERSYS 650 TR' 'VW/SANTANA CL 1800 I' ...
#  'VOLVO/NL12 360 4X2R EDC' 'I/DUCATI HYPERMOTARD1100'
#  'SCANIA/G 440 B6X4 CS']
#
# Coluna: DESC_COR_VEICULO
# Categorias únicas: ['Vermelho' 'Verde' 'Preta' 'Branco' 'Marrom' 'Prata' 'Bege' 'Cinza'
#  'Azul' 'Laranja' 'Dourada' 'Amarelo' 'Roxa' 'Fantasia' 'Rosa'
#  'Não Informado' 'Grena']

# %% [markdown]
# * Corrigindo nomes das cidade

# %%
# Verificar se há cidades que começam com 'S.'
cidades_abreviadas = [cidade for cidade in df['CIDADE'].unique() if cidade.startswith('S.')]

print("""Abreviações restantes não corrigidas:
      """, 
cidades_abreviadas)
# Out:
# Abreviações restantes não corrigidas:
#        ['S.PAULO', 'S.BRANCA', 'S.JOSE DOS CAMPOS', 'S.SEBASTIAO', 'S.BENTO DO SAPUCAI', 'S.ANTONIO DE POSSE', 'S.ERNESTINA', 'S.LUCIA', 'S.JOSE DA BELA VISTA', 'S.ANTONIO DA ALEGRIA', 'S.SIMAO', 'S.JOAQUIM DA BARRA', 'S.CARLOS', 'S.RITA PASSA QUATRO', 'S.CRUZ DO RIO PARDO', 'S.FE DO SUL', 'S.JOSE DO RIO PRETO', 'S.VICENTE', 'S.MIGUEL ARCANJO', 'S.ROQUE', 'S.BARBARA D OESTE', 'S.CRUZ DAS PALMEIRAS', 'S.JOSE DO RIO PARDO', 'S.CRUZ DA CONCEICAO', 'S.PEDRO', 'S.GERTRUDES', 'S.ANTONIO DO JARDIM', 'S.JOAO DA BOA VISTA', 'S.SEBASTIAO DA GRAMA', 'S.ISABEL', 'S.BERNARDO DO CAMPO', 'S.CAETANO DO SUL', 'S.ANDRE', 'S.LOURENCO DA SERRA', 'S.LUIZ DO PARAITINGA', 'S.CRUZ DA ESPERANCA', 'S.ROSA DE VITERBO', 'S.MANUEL', 'S.ALBERTINA', 'S.FRANCISCO', 'S.JOAO DE IRACEMA', 'S.ADELIA', 'S.ANASTACIO', 'S.PEDRO DO TURVO', 'S.JOSE DO BARREIRO', 'S.ANTONIO DO PINHAL', 'S.ANTONIO DE ARACANGUA', 'S.MARIA DA SERRA', 'S.EXPEDITO', 'S.JOAO DUAS PONTES', 'S.JOAO DO PAU D ALHO']

# %%
cidade_corrigidas = {
    'S.PAULO': 'SÃO PAULO',
    'S.BRANCA': 'SÃO BRANCA',
    'S.JOSE DOS CAMPOS': 'SÃO JOSÉ DOS CAMPOS',
    'S.SEBASTIAO': 'SÃO SEBASTIÃO',
    'S.BENTO DO SAPUCAI': 'SÃO BENTO DO SAPUCAÍ',
    'S.ANTONIO DE POSSE': 'SANTO ANTÔNIO DE POSSE',
    'S.ERNESTINA': 'SANTA ERNESTINA',
    'S.LUCIA': 'SANTA LÚCIA',
    'S.JOSE DA BELA VISTA': 'SÃO JOSÉ DA BELA VISTA',
    'S.ANTONIO DA ALEGRIA': 'SANTO ANTÔNIO DA ALEGRIA',
    'S.SIMAO': 'SÃO SIMÃO',
    'S.JOAQUIM DA BARRA': 'SÃO JOAQUIM DA BARRA',
    'S.CARLOS': 'SÃO CARLOS',
    'S.RITA PASSA QUATRO': 'SANTA RITA DO PASSA QUATRO',
    'S.CRUZ DO RIO PARDO': 'SANTA CRUZ DO RIO PARDO',
    'S.FE DO SUL': 'SANTA FÉ DO SUL',
    'S.JOSE DO RIO PRETO': 'SÃO JOSÉ DO RIO PRETO',
    'S.VICENTE': 'SÃO VICENTE',
    'S.MIGUEL ARCANJO': 'SÃO MIGUEL ARCANJO',
    'S.ROQUE': 'SÃO ROQUE',
    'S.BARBARA D OESTE': 'SANTA BÁRBARA D\'OESTE',
    'S.CRUZ DAS PALMEIRAS': 'SANTA CRUZ DAS PALMEIRAS',
    'S.JOSE DO RIO PARDO': 'SÃO JOSÉ DO RIO PARDO',
    'S.CRUZ DA CONCEICAO': 'SANTA CRUZ DA CONCEIÇÃO',
    'S.PEDRO': 'SÃO PEDRO',
    'S.GERTRUDES': 'SANTA GERTRUDES',
    'S.ANTONIO DO JARDIM': 'SANTO ANTÔNIO DO JARDIM',
    'S.JOAO DA BOA VISTA': 'SÃO JOÃO DA BOA VISTA',
    'S.SEBASTIAO DA GRAMA': 'SÃO SEBASTIÃO DA GRAMA',
    'S.ISABEL': 'SANTA ISABEL',
    'S.BERNARDO DO CAMPO': 'SÃO BERNARDO DO CAMPO',
    'S.CAETANO DO SUL': 'SÃO CAETANO DO SUL',
    'S.ANDRE': 'SANTO ANDRÉ',
    'S.LOURENCO DA SERRA': 'SÃO LOURENÇO DA SERRA',
    'S.LUIZ DO PARAITINGA': 'SÃO LUÍS DO PARAITINGA',
    'S.CRUZ DA ESPERANCA': 'SANTA CRUZ DA ESPERANÇA',
    'S.ROSA DE VITERBO': 'SANTA ROSA DE VITERBO',
    'S.MANUEL': 'SÃO MANUEL',
    'S.ALBERTINA': 'SANTA ALBERTINA',
    'S.FRANCISCO': 'SÃO FRANCISCO',
    'S.JOAO DE IRACEMA': 'SÃO JOÃO DE IRACEMA',
    'S.ADELIA': 'SANTA ADÉLIA',
    'S.ANASTACIO': 'SANTO ANASTÁCIO',
    'S.PEDRO DO TURVO': 'SÃO PEDRO DO TURVO',
    'S.JOSE DO BARREIRO': 'SÃO JOSÉ DO BARREIRO',
    'S.ANTONIO DO PINHAL': 'SANTO ANTÔNIO DO PINHAL',
    'S.ANTONIO DE ARACANGUA': 'SANTO ANTÔNIO DO ARACANGUÁ',
    'S.MARIA DA SERRA': 'SANTA MARIA DA SERRA',
    'S.EXPEDITO': 'SANTO EXPEDITO',
    'S.JOAO DUAS PONTES': 'SÃO JOÃO DAS DUAS PONTES',
    'S.JOAO DO PAU D ALHO': 'SÃO JOÃO DO PAU D\'ALHO'
}

df['CIDADE'] = df['CIDADE'].replace(cidade_corrigidas)

# %%
df
# Out:
#        DATA_OCORRENCIA_BO HORA_OCORRENCIA  ANO_BO  NUM_BO  \
# 0              2022-11-24        17:40:00    2022  JS5624
# 1              2022-11-24        17:40:00    2022  JS5624
# 2              2022-11-24        17:40:00    2022  JS5624
# 3              2022-11-24        17:40:00    2022  JS5624
# 4              2022-11-24        17:40:00    2022  JS5624
# ...                   ...             ...     ...     ...
# 413113         2024-05-04        05:53:00    2024  GE3228
# 413114         2024-05-14        16:35:48    2024  GQ5787
# 413115         2024-05-14        16:35:48    2024  GQ5787
# 413116         2024-05-14        16:35:48    2024  GQ5787
# 413117         2024-05-14        16:35:48    2024  GQ5787
#
#        FLAG_ATO_INFRACIONAL     CIDADE       BAIRRO         CEP  \
# 0                         N  SÃO PAULO    LIBERDADE   1502000.0
# 1                         N  SÃO PAULO    LIBERDADE   1502000.0
# 2                         N  SÃO PAULO    LIBERDADE   1502000.0
# 3                         N  SÃO PAULO    LIBERDADE   1502000.0
# 4                         N  SÃO PAULO    LIBERDADE   1502000.0
# ...                     ...        ...          ...         ...
# 413113                    N  GUARULHOS    AEROPORTO   7190971.0
# 413114                    N     SANTOS  PORTO SABOO  11095650.0
# 413115                    N     SANTOS  PORTO SABOO  11095650.0
# 413116                    N     SANTOS  PORTO SABOO  11095650.0
# 413117                    N     SANTOS  PORTO SABOO  11095650.0
#
#                                LOGRADOURO  NUMERO_LOGRADOURO   LATITUDE  \
# 0                    AVENIDA DA LIBERDADE              130.0 -23.557245
# 1                    AVENIDA DA LIBERDADE              130.0 -23.557245
# 2                    AVENIDA DA LIBERDADE              130.0 -23.557245
# 3                    AVENIDA DA LIBERDADE              130.0 -23.557245
# 4                    AVENIDA DA LIBERDADE              130.0 -23.557245
# ...                                   ...                ...        ...
# 413113       RODOVIA HÉLIO SMIDT - SP 019              815.0 -23.423160
# 413114  AVENIDA ENGENHEIRO AUGUSTO BARATA                1.0 -23.928273
# 413115  AVENIDA ENGENHEIRO AUGUSTO BARATA                1.0 -23.928273
# 413116  AVENIDA ENGENHEIRO AUGUSTO BARATA                1.0 -23.928273
# 413117  AVENIDA ENGENHEIRO AUGUSTO BARATA                1.0 -23.928273
#
#         LONGITUDE DESCR_OCORRENCIA_VEICULO DESCR_TIPO_VEICULO  \
# 0      -46.636418    Localizado / Entregue          Motociclo
# 1      -46.636418    Localizado / Entregue          Motociclo
# 2      -46.636418    Localizado / Entregue          Motociclo
# 3      -46.636418    Localizado / Entregue          Motociclo
# 4      -46.636418    Localizado / Entregue          Motociclo
# ...           ...                      ...                ...
# 413113 -46.486105                  Roubado          Motociclo
# 413114 -46.337792                  Roubado    Caminhão trator
# 413115 -46.337792                  Roubado    Caminhão trator
# 413116 -46.337792                  Roubado       Semi-reboque
# 413117 -46.337792                  Roubado       Semi-reboque
#
#            DESCR_MARCA_VEICULO DESC_COR_VEICULO
# 0             HONDA/CG 160 FAN         Vermelho
# 1       KAWASAKI/VERSYS 650 TR            Verde
# 2             HONDA/CG 160 FAN         Vermelho
# 3       KAWASAKI/VERSYS 650 TR            Verde
# 4             HONDA/CG 160 FAN         Vermelho
# ...                        ...              ...
# 413113    YAMAHA/XTZ250 LANDER            Preta
# 413114    SCANIA/G 440 B6X4 CS           Branco
# 413115    SCANIA/G 440 B6X4 CS           Branco
# 413116    SR/NOMA SRAT3E SRCAT            Preta
# 413117    SR/NOMA SRAT3E SRCAT            Preta
#
# [413118 rows x 16 columns]

# %% [markdown]
# ### Salvando dados tratados

# %%
df['BAIRRO'] = df['BAIRRO'].astype(str)
data_save_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'data', 'processed','VeiculosSubtraidos.parquet'))
df.to_parquet(data_save_path, index=False)
