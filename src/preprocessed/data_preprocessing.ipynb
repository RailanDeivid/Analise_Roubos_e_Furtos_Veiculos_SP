# %%
import pandas as pd
import os, glob
import warnings
warnings.filterwarnings("ignore")

# %%
# Diretório onde estão os arquivos Excel
db_path = os.path.join(os.getcwd(), '..', '..', 'data','raw')                 
todos_arquivos = glob.glob(os.path.join(db_path, "*.xlsx"))    

# Inicializa uma lista vazia para armazenar os DataFrames individuais
dfs = []

# Itera sobre cada arquivo Excel encontrado
for arquivo in todos_arquivos:
    # Lê o arquivo excel e adiciona o DataFrame à lista
    df_temp = pd.read_excel(arquivo)
    dfs.append(df_temp)

# Concatena todos os DataFrames da lista em um único DataFrame
df = pd.concat(dfs, ignore_index=True)

# Exibe as primeiras linhas do DataFrame resultante
df.head()
# Out:
#    ID_DELEGACIA NOME_DEPARTAMENTO    NOME_SECCIONAL            NOME_DELEGACIA  \
# 0         20210             DECAP  DEL.SEC.5º LESTE  10º D.P. PENHA DE FRANCA
# 1         20210             DECAP  DEL.SEC.5º LESTE  10º D.P. PENHA DE FRANCA
# 2         20210             DECAP  DEL.SEC.5º LESTE  10º D.P. PENHA DE FRANCA
# 3         20210             DECAP  DEL.SEC.5º LESTE  10º D.P. PENHA DE FRANCA
# 4         20210             DECAP  DEL.SEC.5º LESTE  10º D.P. PENHA DE FRANCA
#
#   NOME_MUNICIPIO  ANO_BO  NUM_BO  VERSAO NOME_DEPARTAMENTO_CIRC  \
# 0        S.PAULO    2022  JS5624       3                  DECAP
# 1        S.PAULO    2022  JS5624       3                  DECAP
# 2        S.PAULO    2022  JS5624       3                  DECAP
# 3        S.PAULO    2022  JS5624       3                  DECAP
# 4        S.PAULO    2022  JS5624       3                  DECAP
#
#   NOME_SECCIONAL_CIRC  ... DESCR_TIPO_VEICULO     DESCR_MARCA_VEICULO  \
# 0   DEL.SEC.1º CENTRO  ...          Motociclo        HONDA/CG 160 FAN
# 1   DEL.SEC.1º CENTRO  ...          Motociclo  KAWASAKI/VERSYS 650 TR
# 2   DEL.SEC.1º CENTRO  ...          Motociclo        HONDA/CG 160 FAN
# 3   DEL.SEC.1º CENTRO  ...          Motociclo  KAWASAKI/VERSYS 650 TR
# 4   DEL.SEC.1º CENTRO  ...          Motociclo        HONDA/CG 160 FAN
#
#   ANO_FABRICACAO ANO_MODELO PLACA_VEICULO DESC_COR_VEICULO MES   ANO CIDADE.1  \
# 0         2022.0     2022.0       GIE5D17         Vermelho   1  2023      NaN
# 1         2022.0     2023.0       FXY5G62            Verde   1  2023      NaN
# 2         2022.0     2022.0       GIE5D17         Vermelho   1  2023      NaN
# 3         2022.0     2023.0       FXY5G62            Verde   1  2023      NaN
# 4         2022.0     2022.0       GIE5D17         Vermelho   1  2023      NaN
#
#   DESC_NATUREZA_LOCAL
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 52 columns]
